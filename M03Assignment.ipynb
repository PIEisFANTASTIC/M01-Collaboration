# %%
#7.4
things = ["mozzarella", "cinderella", "salmonella"]

# %%
#7.5
things = ["mozzarella", "cinderella", "salmonella"]
things[1] = things[1].title()
print(things)
# Yes, it does change the list.
# Out:
# ['mozzarella', 'Cinderella', 'salmonella']

# %%
#7.6
things = ["mozzarella", "cinderella", "salmonella"]
things[0] = things[0].upper()
print(things)
# Out:
# ['MOZZARELLA', 'cinderella', 'salmonella']

# %%
#7.7
things = ["mozzarella", "cinderella", "salmonella"]
things.remove("salmonella")
print(things)
# Out:
# ['mozzarella', 'cinderella']

# %%
#9.1
def good():
    return ['Harry', 'Ron', 'Hermione']
print(good())
# Out:
# ['Harry', 'Ron', 'Hermione']

# %%
#9.2
def get_ods():
    odds = []
    for x in range(10):
        if x%2 == 1:
            odds.append(x)
    return odds

for odd in get_ods():
    if get_ods().index(odd) == 2:
        print(odd)
# Out:
# 5
