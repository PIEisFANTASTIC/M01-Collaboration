# %%
# 4.1
import random
secret = 7
guess = random.randint(1,10)

if guess < secret:
    print("Too low")
elif guess > secret:
    print("Too high")
else:
    print("Just right")
    
print("The secret number was %i and my guess is %i." % (secret, guess))
# Out:
# Too high
# The secret number was 7 and my guess is 10.

# %%
#4.2
import random
small = random.choice([True, False])
green = random.choice([True, False])
print("Small is %s, green is %s." % (small, green))

if green and small:
    print("pea")
elif green and not small:
    print("watermelon")
elif not green and small:
    print("cherry")
else:
    print("pumpkin")
# Out:
# Small is True, green is False.
# cherry

# %%
# 6.1
num_list = [3, 2, 1, 0]
for number in num_list:
    print(number)
# Out:
# 3
# 2
# 1
# 0

# %%
# 6.2
guess_me = 7
number = 1
while number <= guess_me:
    if number < guess_me:
        print("Too low")
    elif number > guess_me:
        print("Oops")
        break
    else:
        print("Found it!")
        break
    number += 1
# Out:
# Too low
# Too low
# Too low
# Too low
# Too low
# Too low
# Found it!

# %%
# 6.3
guess_me = 5
for number in range(10):
    if number < guess_me:
        print("Too low")
    elif number > guess_me:
        print("Oops")
        break
    else:
        print("Found it!")
        break
# Out:
# Too low
# Too low
# Too low
# Too low
# Too low
# Found it!
